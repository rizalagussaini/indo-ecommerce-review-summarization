# %% [markdown]
# ### Fine-tuning

# %%
# !pip install -q datasets transformers accelerate bitsandbytes peft evaluate
# !pip install -q -U bitsandbytes
# !pip install --upgrade transformers
# !pip install datasets evaluate rouge-score
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting transformers
#   Downloading transformers-4.52.3-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Downloading transformers-4.52.3-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 90.3 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# Successfully installed transformers-4.52.3
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=7718573a106f6decb9f8a837ffa41bae51b777dd9426f9639bb66dd3d52c99d3
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from huggingface_hub import login
login("hf_xxxxxxxxxxxxxxxxxxxxx")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tarfile

# Path to your .tar.gz file
tar_file_path = '/content/liputan6_data.tar.gz'

# Extract the .tar.gz file
with tarfile.open(tar_file_path, 'r:gz') as tar:
    tar.extractall(path='extracted_data')

# %%
import os
import json

data_dir = '/content/extracted_data/liputan6_data/canonical/train'
combined_dataset = []

for root, dirs, files in os.walk(data_dir):
    for file in files:
        if file.endswith('.json'):
            with open(os.path.join(root, file), 'r', encoding='utf-8') as f:
                try:
                    data = json.load(f)
                    if 'clean_article' in data and 'clean_summary' in data:
                        article = ' '.join([' '.join(sent) for sent in data['clean_article']])
                        summary = ' '.join([' '.join(sent) for sent in data['clean_summary']])
                        combined_dataset.append({'text': article, 'summary': summary})
                except Exception as e:
                    print(f"Skipping {file}: {e}")

# %%
from datasets import Dataset

# Convert to HuggingFace Dataset format
hf_dataset = Dataset.from_list(combined_dataset)
hf_dataset = hf_dataset.select(range(500))  ### Ambil sebagian dari dataset (hanya 500)
#kurangi value (500) menjadi 450 (-50) jikalau eror kar

# === Format dataset for summarization ===
def format_instruction(example):
    article = example["text"]
    summary = example["summary"]
    prompt = f"Buat ringkasan dari teks berikut:\n{article.strip()}\n"
    return {"text": prompt, "summary": summary}

# Apply the formatting function to the dataset
hf_dataset = hf_dataset.map(format_instruction, remove_columns=hf_dataset.column_names)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
# === Split into train/eval sets ===
split_dataset = hf_dataset.train_test_split(test_size=0.2, seed=42)
train_dataset = split_dataset["train"]
eval_dataset = split_dataset["test"]

# %%
import os
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, TaskType
from transformers import BitsAndBytesConfig

# %%
# === Load Tokenizer and Model (Quantized) ===
# model_name = "mistralai/Mistral-7B-Instruct-v0.2"
model_name = "NousResearch/Nous-Hermes-llama-2-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config,
    torch_dtype=torch.float16
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/647 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/13.5G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/175 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.

# %%
# Jika error muncul saat fine-tuning, kamu bisa coba lihat nama modul yang cocok dengan:
# print([name for name, _ in model.named_modules() if "q_proj" in name or "v_proj" in name])

# %%
# !pip uninstall numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/numpy-config
#     /usr/local/lib/python3.11/dist-packages/numpy-2.0.2.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libgfortran-040039e1-0352e75f.so.5.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libquadmath-96973f99-934c22de.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libscipy_openblas64_-99b71e71.so
#     /usr/local/lib/python3.11/dist-packages/numpy/*
# Proceed (Y/n)? Y
#   Successfully uninstalled numpy-2.0.2
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 99.6 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
from peft import PeftModel, prepare_model_for_kbit_training, LoraConfig, get_peft_model, TaskType
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer

# === Prepare model for LoRA fine-tuning ===
model.gradient_checkpointing_enable()
model.enable_input_require_grads()
model = prepare_model_for_kbit_training(model)

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.CAUSAL_LM,
)

if not isinstance(model, PeftModel) and not hasattr(model, "peft_config"):
    model = get_peft_model(model, lora_config)

model.train()

# === Tokenization ===
def tokenize(example):
    prompts = [f"[INST] Buat ringkasan dari artikel berikut:\n{text.strip()}\n[/INST]" for text in example["text"]]
    full_inputs = [prompt + " " + summary.strip() for prompt, summary in zip(prompts, example["summary"])]

    tokens = tokenizer(full_inputs, truncation=True, padding="max_length", max_length=512)
    tokens["labels"] = tokens["input_ids"].copy()
    return tokens

tokenized_train = train_dataset.map(tokenize, batched=True)
tokenized_eval = eval_dataset.map(tokenize, batched=True)

tokenized_train.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
tokenized_eval.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# === Training Arguments (choose either bf16 or fallback to fp32) ===
training_args = TrainingArguments(
    output_dir="./llama7b-finetuned-liputan6",
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    num_train_epochs=3,
    logging_steps=10,
    save_steps=100,
    save_total_limit=2,
    bf16=True,  # ✅ Use bf16 if your GPU supports it (e.g., T4, A100)
    # fp16=False,  # ❌ Do not use fp16 with 8-bit optimizer on Colab unless you know it's safe
    gradient_checkpointing=True,
    optim="paged_adamw_8bit",  # Still using bitsandbytes optimizer
    learning_rate=2e-5,
    lr_scheduler_type="cosine",
    warmup_steps=10,
    report_to="none"
)

# === Trainer ===
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_eval,
    tokenizer=tokenizer,
)

trainer.train()
# Out:
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# <ipython-input-9-8260b2996b9c>:58: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 3:44:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.094600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.023800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.971200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.948700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.868600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.802200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.762500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.750500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.716400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.719700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.680500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.740200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.648900</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.692700</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.710700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=150, training_loss=1.8087555694580078, metrics={'train_runtime': 13546.7387, 'train_samples_per_second': 0.089, 'train_steps_per_second': 0.011, 'total_flos': 2.4372773388288e+16, 'train_loss': 1.8087555694580078, 'epoch': 3.0})

# %%
from peft import PeftModel

# Assuming `model` is your LoRA model and has been trained
model.push_to_hub("Blebbyblub/llama7b-finetuned-liputan6")
tokenizer.push_to_hub("Blebbyblub/llama7b-finetuned-liputan6")
# Out:
# adapter_model.safetensors:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Blebbyblub/llama7b-finetuned-liputan6/commit/cc61eb48703379702ebfb84de00156d7560ac97a', commit_message='Upload tokenizer', commit_description='', oid='cc61eb48703379702ebfb84de00156d7560ac97a', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Blebbyblub/llama7b-finetuned-liputan6', endpoint='https://huggingface.co', repo_type='model', repo_id='Blebbyblub/llama7b-finetuned-liputan6'), pr_revision=None, pr_num=None)

# %% [markdown]
# ### Evaluation

# %%
# Install necessary packages if they are not already installed
# !pip install -q transformers accelerate bitsandbytes evaluate

from transformers import AutoTokenizer, AutoModelForCausalLM
from accelerate import Accelerator
import torch
import os
from datasets import Dataset
import evaluate

# Set up an offload directory on the disk (make sure the directory exists or create it)
offload_dir = "/content/model_offload"

if not os.path.exists(offload_dir):
    os.makedirs(offload_dir)

# Initialize Accelerator for managing device placement
accelerator = Accelerator()

# Enable 4-bit quantization to reduce memory usage
from transformers import BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,  # Use 4-bit quantization
    bnb_4bit_quant_type="nf4",  # Type of quantization
    bnb_4bit_compute_dtype=torch.float16,  # Compute in FP16 for further memory reduction
)

# Load the model and tokenizer from Hugging Face hub with quantization
model_name = "Blebbyblub/llama7b-finetuned-liputan6"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load the model with the quantization configuration
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,  # Use FP16 to further reduce memory usage
)

# Move model to accelerator's device (GPU or CPU)
model = accelerator.prepare(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/789 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/647 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/13.5G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/175 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# adapter_model.safetensors:   0%|          | 0.00/16.8M [00:00<?, ?B/s]

# %%
from tqdm import tqdm # Apple to apple
from evaluate import load as load_metric
import re

# === Load ROUGE metric ===
rouge = load_metric("rouge")

# === Summarize function ===
def summarize_text(text, max_new_tokens=150):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=2048, padding=True).to(model.device)
    outputs = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        pad_token_id=tokenizer.eos_token_id
    )
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

    # Extract only the "Ringkasan :" part if present
    if "Ringkasan :" in decoded:
        summary = decoded.split("Ringkasan :", 1)[1].strip()
    else:
        summary = decoded  # fallback if format isn't found

    # Optional: remove common trailing sources like "( OMI/Putu Setiawan )"
    summary = re.sub(r'\(\s?[A-Z]+\/[A-Za-z\s]+\s?\)', '', summary).strip()

    return summary

# === Run evaluation ===
predictions = []
references = []

print("🚀 Running evaluation without prompt formatting...")
for example in tqdm(eval_dataset, desc="Evaluating"):
    text = example["text"]
    reference = example["summary"]

    prediction = summarize_text(text)
    predictions.append(prediction)
    references.append(reference)

# === Compute ROUGE scores ===
results = rouge.compute(predictions=predictions, references=references)

# === Display the results ===
print("\n📊 ROUGE Evaluation Results:")
for key, value in results.items():
    print(f"{key}: {value:.4f}")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# 🚀 Running evaluation without prompt formatting...
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   1%|          | 1/100 [00:21<34:42, 21.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   2%|▏         | 2/100 [00:39<31:31, 19.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   3%|▎         | 3/100 [00:53<27:53, 17.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   4%|▍         | 4/100 [01:03<22:47, 14.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   5%|▌         | 5/100 [01:12<19:37, 12.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   6%|▌         | 6/100 [01:22<17:50, 11.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   7%|▋         | 7/100 [01:32<16:56, 10.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   8%|▊         | 8/100 [01:40<15:41, 10.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   9%|▉         | 9/100 [01:50<15:05,  9.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  10%|█         | 10/100 [02:07<18:06, 12.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  11%|█         | 11/100 [02:16<16:31, 11.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  12%|█▏        | 12/100 [02:25<15:45, 10.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  13%|█▎        | 13/100 [02:35<14:52, 10.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  14%|█▍        | 14/100 [02:44<14:13,  9.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  15%|█▌        | 15/100 [02:54<14:20, 10.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  16%|█▌        | 16/100 [03:04<13:54,  9.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  17%|█▋        | 17/100 [03:13<13:27,  9.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  18%|█▊        | 18/100 [03:22<13:09,  9.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  19%|█▉        | 19/100 [03:31<12:42,  9.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  20%|██        | 20/100 [03:41<12:30,  9.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  21%|██        | 21/100 [03:50<12:22,  9.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  22%|██▏       | 22/100 [04:00<12:15,  9.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  23%|██▎       | 23/100 [04:09<12:09,  9.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  24%|██▍       | 24/100 [04:19<12:17,  9.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  25%|██▌       | 25/100 [04:28<11:51,  9.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  26%|██▌       | 26/100 [04:38<11:42,  9.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  27%|██▋       | 27/100 [04:47<11:30,  9.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  28%|██▊       | 28/100 [04:56<11:12,  9.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  29%|██▉       | 29/100 [05:07<11:40,  9.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  30%|███       | 30/100 [05:16<11:12,  9.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:
/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  89%|████████▉ | 89/100 [14:16<01:40,  9.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  90%|█████████ | 90/100 [14:26<01:33,  9.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  91%|█████████ | 91/100 [14:36<01:24,  9.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  92%|█████████▏| 92/100 [14:45<01:15,  9.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  93%|█████████▎| 93/100 [14:54<01:04,  9.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  94%|█████████▍| 94/100 [15:04<00:55,  9.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  95%|█████████▌| 95/100 [15:13<00:46,  9.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  96%|█████████▌| 96/100 [15:22<00:37,  9.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  97%|█████████▋| 97/100 [15:31<00:27,  9.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  98%|█████████▊| 98/100 [15:40<00:18,  9.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  99%|█████████▉| 99/100 [15:50<00:09,  9.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating: 100%|██████████| 100/100 [15:59<00:00,  9.59s/it]
# 📊 ROUGE Evaluation Results:
# rouge1: 0.1794
# rouge2: 0.1214
# rougeL: 0.1562
# rougeLsum: 0.1557

# %%
from tqdm import tqdm # Adjusted untuk llama
from evaluate import load as load_metric
import re

# === Load ROUGE metric ===
rouge = load_metric("rouge")

# === Summarize function ===
def summarize_text(text, max_new_tokens=150):
    prompt = f"Buat ringkasan dari teks berikut:\n{text}"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=2048, padding=True).to(model.device)

    outputs = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        num_beams=4,
        early_stopping=True,
        repetition_penalty=1.2,
        no_repeat_ngram_size=3,
        pad_token_id=tokenizer.eos_token_id
    )
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

    # Remove prompt-like artifacts
    summary = re.sub(r"^Buat ringkasan.*?:", "", decoded, flags=re.IGNORECASE).strip()
    summary = re.sub(r'\(\s?[A-Z]+\/[A-Za-z\s]+\s?\)', '', summary).strip()

    return summary

# === Run evaluation ===
predictions = []
references = []

print("🚀 Running evaluation without prompt formatting...")
for example in tqdm(eval_dataset, desc="Evaluating"):
    text = example["text"]
    reference = example["summary"]

    prediction = summarize_text(text)
    predictions.append(prediction)
    references.append(reference)

# === Compute ROUGE scores ===
results = rouge.compute(predictions=predictions, references=references)

# === Display the results ===
print("\n📊 ROUGE Evaluation Results:")
for key, value in results.items():
    print(f"{key}: {value:.4f}")
# Out:
# 🚀 Running evaluation without prompt formatting...
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   1%|          | 1/100 [00:08<13:22,  8.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   2%|▏         | 2/100 [00:23<20:00, 12.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   3%|▎         | 3/100 [00:38<22:14, 13.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   4%|▍         | 4/100 [00:54<23:20, 14.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   5%|▌         | 5/100 [00:58<17:13, 10.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   6%|▌         | 6/100 [01:28<27:11, 17.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   7%|▋         | 7/100 [01:51<29:45, 19.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   8%|▊         | 8/100 [01:58<23:24, 15.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   9%|▉         | 9/100 [02:05<18:55, 12.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  10%|█         | 10/100 [02:18<19:08, 12.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  11%|█         | 11/100 [02:22<15:03, 10.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  12%|█▏        | 12/100 [02:46<20:54, 14.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  13%|█▎        | 13/100 [02:52<16:55, 11.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  14%|█▍        | 14/100 [02:58<14:17,  9.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  15%|█▌        | 15/100 [03:13<16:33, 11.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  16%|█▌        | 16/100 [03:32<19:22, 13.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  17%|█▋        | 17/100 [03:36<14:51, 10.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  18%|█▊        | 18/100 [03:54<17:45, 12.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  19%|█▉        | 19/100 [04:03<16:04, 11.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  20%|██        | 20/100 [04:22<18:33, 13.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:
/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  77%|███████▋  | 77/100 [17:07<05:28, 14.27s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  78%|███████▊  | 78/100 [17:17<04:43, 12.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  79%|███████▉  | 79/100 [17:21<03:34, 10.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  80%|████████  | 80/100 [17:43<04:33, 13.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  81%|████████  | 81/100 [17:49<03:35, 11.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  82%|████████▏ | 82/100 [18:05<03:53, 12.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  83%|████████▎ | 83/100 [18:11<03:04, 10.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  84%|████████▍ | 84/100 [18:29<03:26, 12.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  85%|████████▌ | 85/100 [18:35<02:44, 10.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  86%|████████▌ | 86/100 [18:39<02:00,  8.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  87%|████████▋ | 87/100 [18:45<01:42,  7.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  88%|████████▊ | 88/100 [18:51<01:27,  7.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  89%|████████▉ | 89/100 [19:09<01:56, 10.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  90%|█████████ | 90/100 [19:24<01:59, 11.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  91%|█████████ | 91/100 [19:42<02:03, 13.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  92%|█████████▏| 92/100 [20:04<02:09, 16.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  93%|█████████▎| 93/100 [20:10<01:32, 13.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  94%|█████████▍| 94/100 [20:21<01:13, 12.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  95%|█████████▌| 95/100 [20:24<00:48,  9.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  96%|█████████▌| 96/100 [20:41<00:46, 11.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  97%|█████████▋| 97/100 [20:56<00:38, 12.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  98%|█████████▊| 98/100 [21:01<00:20, 10.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  99%|█████████▉| 99/100 [21:14<00:11, 11.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating: 100%|██████████| 100/100 [21:27<00:00, 12.88s/it]
# 📊 ROUGE Evaluation Results:
# rouge1: 0.2238
# rouge2: 0.1534
# rougeL: 0.1891
# rougeLsum: 0.1907

# %%
# Print an example result
print("\n=== Sample Summary ===")
# print("Original Text:\n", eval_dataset[0]["prompt"])
print("\nReference Summary:\n", references[0])
print("\nModel Prediction:\n", predictions[0])
# Out:
# === Sample Summary ===
#
# Reference Summary:
#  Brasil tidak memberi angin buat Chile . Meski sudah memastikan diri lolos ke putaran final PD 2010 , Brasil tetap tampil solid untuk menundukkan Chile 4-2 ( 2-1 ) di Salvador , Kamis pagi WIB .
#
# Model Prediction:
#  Buat ringkasan dari teks berikut:
# Liputan6 . com , Salvador : Meskipun sudah memastikan diri melaju ke Afrika Selatan untuk musim panas tahun depan , Brasil tetap bersungguh-sungguh ketika menjamu Chile dalam lanjutan kualifikasi Piala Dunia di Salvador , Rabu ( 9/9 ) atau Kamis dini hari WIB . Ditandai hat-trick Nilmar , Selecao menang 4-2 ( 2-1 ) . Brasil turun tanpa Robinho , Kaka dan Luis Fabiano falam pertandingan yang diwarnai turunnya hujan lebat . Akan tetapi Nilmar mampu menjawab keraguan banyak orang bahwa tuan rumah akan memberi partai ini untuk Chile dengan tujuan menyingkirkan Argentina yang beberapa saat sebelumnya kalah dari Paraguay . Namun Brasil tetap bersungguh-sungguh mempertahankan kehormatan . Nilmar yang mnusim panas ini dibeli Villarreal membuat Brasil memimpin 1-0 pada menit ke-31 . Julio Baptista yang dipanggil Dunga untuk menggantikan Kaka menambah keunggulan pada menit ke-40 . Namun menjelang babak pertama usai Humberto Suazo mampu memperkecil ketinggalan Chile dari eksekusi sempurna penalti . Selepas turun minum pertandingan berjalan panas . Babak kedua baru berjalan empat menit Felipe Melo menerima kartu merah langsung . Unggul jumlah pemain Chile menyamakan kedudukan melalui Humberto pada menit ke-52 . Brasil memiliki mental juara . Ketika pertandingan berjalan 73 menit , Nilmar membawa Brasil unggul kembali . Dua menit kemudian Nilmar memastikan kemenangan 4-2 sekaligus membukukan hat-trick-nya . Kesempatan Chile meraih poin seakan sirna ketika Alexis Sanchez menerima kartu kuning keduanya pada menit ke-76 . Bermain dengan jumlah pemain yang kembali berimbang , Brasil dengan mudah mempertahankan kemenangan hingga peluit panjang berbunyi . Hasil tersebut membuat Brasil menjauh tiga poin dari Paraguay . Sementara Chile harus menunda tiket ke Afsel dan tertahan di peringkat ketiga dengan jumlah poin 27 . Meski begitu Chile dipastikan aman untuk jatah play-off , milik peringkat kelima di Zona CONMEBOL . Sementara itu di partai lainnya Venezuela membuka kans mencatat sejarah tampil di putaran final Piala Dunia untuk pertama kalinya setelah mengalahkan Peru 3-1 ( 1-1 ) di Stadion Olimpico Luis Ramos , Puerto la Cruz . Nicolas Fedor menyumbangkan dua gol pada menit ke-32 dan ke-52 . Peru sempat menyamakan kedudukan melalui gol bunuh diri Juan Fuenmayor empat menit sebelum turun minum . Ronald Vargas memastikan tiga poin milik tuan rumah setekah melesakan bola ke gawang pada menit ke-70 . Kemenangan itu mengantar Venezuela menempati peringkat ketujuh dengan 21 poin . Mereka terpaut dua poin dari Ekuador di posisi keempat dan satu poin dari Argentina di tempat kelima . ( DIM ) .
# Kata kunci : nilmar , selecao , chile , afsel

# %% [markdown]
# ### Testing for E-commerce Review

# %%
# !pip install -U datasets fsspec huggingface_hub
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (2025.3.2)
# Collecting fsspec
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.31.2)
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.32.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Collecting fsspec
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.13.2)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface_hub)
#   Downloading hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 16.4 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.32.0-py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.3/509.3 kB 32.4 MB/s eta 0:00:00
# Downloading hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 61.4 MB/s eta 0:00:00
# Installing collected packages: hf-xet, fsspec, huggingface_hub, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.31.2
#     Uninstalling huggingface-hub-0.31.2:
#       Successfully uninstalled huggingface-hub-0.31.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.6.0 fsspec-2025.3.0 hf-xet-1.1.2 huggingface_hub-0.32.0

# %%
# Import library yang diperlukan
import re
import pandas as pd
import nltk
nltk.download("stopwords")
import torch
from datasets import load_dataset
from nltk.corpus import stopwords
from huggingface_hub import login
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words("indonesian"))

# Load and clean slang
def load_slang_dictionary():
    slang_dataset = load_dataset("theonlydo/indonesia-slang")['train']
    slang_map = {row["slang"]: row["formal"] for row in slang_dataset}
    slang_patterns = {
        re.compile(rf'\b{re.escape(slang)}\b', re.IGNORECASE): formal
        for slang, formal in slang_map.items()
    }
    return slang_patterns

# Clean + preprocess reviews
def preprocess_text(text, slang_patterns):
    for pattern, formal in slang_patterns.items():
        text = pattern.sub(formal, text)
    words = re.findall(r'\b\w+\b', text.lower())
    cleaned_words = [word for word in words if word not in stop_words]
    return " ".join(cleaned_words)

# Load and preprocess dataset
dataset = load_dataset("dipawidia/ecommerce-product-reviews-sentiment", split="train")
dataset = dataset.remove_columns([col for col in dataset.column_names if col != "review"])
slang_patterns = load_slang_dictionary()
dataset = dataset.map(lambda x: {"review": preprocess_text(x["review"], slang_patterns)})

reviews = [row["review"] for row in dataset.select(range(100))] ### Banyak review yang di ambil (jangan di ubah)
joined_reviews = ". ".join(reviews)
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty
seller. tekonya bersiul ya. kecewa banget toko. nyaring nya gagang nya panas merk maspion. pengiriman pakai shopee express sisanya aman mantap. super fast response order 1 jam barang. mouse connect. respon penjual ok barang sesuai pesanan muantap. barang tanggal 29des smpai2 bayar ongkir ekspres 0 mengecewakan layak lazada. bonus nya pul tokonya amanah terima kasih coba terima kasih lazada. barang aman lengkap bagus. barangnya bagus berfungsi mantap kecewa jasa pengirimannya sih. ditukar pkt langsung diambil pelanggan foto unboxing. bagus sesuai iklan tampilkan dual layar. salah warna wrna pink datangnya wrna biru pengemasan punyaku penyok. maaf kasihh ulasan barang bagus pakingnya rapi smpet foto nya bndung. barang diterima pengiriman sabtu pengirman barang sesuai deskripsi. barang bagus pas dipakai tabungnya muter ujung2nya pakai manual deh alias pakai tangan ken mangkoknya muter. pengiriman pakai sicepat untungnya. lucu banget seduniaaaaaaa woiii semoga semangat skripsian. barang penyok parah gue tau sellernya penyok pas proses pengirimannya keamanan bu ...

# %%
import re
import torch
from tqdm import tqdm

# === Your summarization function ===
def summarize_text(text, max_new_tokens=150):
    prompt = f"Buat ringkasan dari teks berikut:\n{text}"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1048, padding=True).to(model.device)

    outputs = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        num_beams=4,
        early_stopping=True,
        repetition_penalty=1.2,
        no_repeat_ngram_size=3,
        pad_token_id=tokenizer.eos_token_id
    )

    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

    # Clean up extra prompt fragments and attributions
    summary = re.sub(r"^Buat ringkasan.*?:", "", decoded, flags=re.IGNORECASE).strip()
    summary = re.sub(r'\(\s?[A-Z]+\/[A-Za-z\s]+\s?\)', '', summary).strip()

    return summary if summary else decoded.strip()

# === Split input text into token-length-aware chunks ===
def split_into_token_chunks(text, tokenizer, max_tokens=1800):
    sentences = re.split(r'(?<=[.!?])\s+', text)
    chunks = []
    current = ""

    for sentence in sentences:
        temp = (current + " " + sentence).strip() if current else sentence
        tokenized = tokenizer(temp, return_tensors="pt", truncation=False)
        if tokenized["input_ids"].shape[1] <= max_tokens:
            current = temp
        else:
            if current:
                chunks.append(current.strip())
            current = sentence
    if current:
        chunks.append(current.strip())
    return chunks

# === Recursive summarization logic ===
def recursive_summarize(text, max_recursions=5, token_chunk_size=1800):
    current_text = text
    recursion = 0

    while recursion < max_recursions:
        recursion += 1
        print(f"\n⏳ Summarization Round #{recursion}...")

        # Split by token limit
        chunks = split_into_token_chunks(current_text, tokenizer, max_tokens=token_chunk_size)
        print(f"🔹 {len(chunks)} chunks")

        chunk_summaries = []
        for chunk in tqdm(chunks, desc=f"Summarizing Chunks (Round {recursion})"):
            summary = summarize_text(chunk)
            if summary:
                chunk_summaries.append(summary)

        combined_summary = " ".join(chunk_summaries).strip()

        # Token length check
        combined_token_len = len(tokenizer(combined_summary)["input_ids"])
        print(f"🧾 Combined summary token length: {combined_token_len}")

        if combined_token_len <= token_chunk_size or len(chunk_summaries) <= 1:
            print("✅ Stopping recursion.")
            return summarize_text(combined_summary)

        current_text = combined_summary

    print("⚠️ Max recursion reached. Returning last result.")
    return summarize_text(current_text)

# === Example usage ===
joined_reviews = "..."  # your input text here
final_summary = recursive_summarize(joined_reviews)
print("\n📌 FINAL SUMMARY:")
print(final_summary)
# Out:
# ⏳ Summarization Round #1...
# 🔹 1 chunks
# Summarizing Chunks (Round 1):   0%|          | 0/1 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Summarizing Chunks (Round 1): 100%|██████████| 1/1 [00:14<00:00, 14.32s/it]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 🧾 Combined summary token length: 76
# ✅ Stopping recursion.
#
# 📌 FINAL SUMMARY:
# ...dengan menggunakan teknologi informasi dan komunikasi (TIK) sebagai salah satu alat yang dapat digunakan untuk meningkatkan efisiensi dan efektivitas dalam pengelolaan keuangan perusahaan. Teknologi ini juga dapat memberikan informasi yang lebih akurat dan cepat dibandingkan dengan metode manual.

# %%
# Longer review input
input_text = """
[INST] Ringkas ulasan berikut menjadi satu paragraf singkat tanpa mengulang kata-kata secara utuh:\n
Buat ringkasan dari teks berikut ke dalam satu paragraf:
Saya membeli produk ini karena banyak review positif yang saya lihat sebelumnya. Setelah barang sampai, saya langsung coba dan ternyata kualitasnya sangat memuaskan. Materialnya terasa kokoh dan sesuai deskripsi. Pengiriman juga sangat cepat, hanya butuh dua hari untuk sampai di rumah saya di Jakarta. Seller sangat komunikatif dan membantu menjawab semua pertanyaan saya sebelum membeli. Selain itu, kemasan produk sangat rapi dan aman, tidak ada kerusakan sedikit pun. Harganya juga cukup bersaing dibanding toko lain. Saya sudah coba pakai selama seminggu dan sejauh ini tidak ada kendala. Benar-benar pengalaman belanja yang memuaskan dan saya sangat merekomendasikan produk ini kepada orang lain.
[/INST]
"""

# Tokenize input
inputs = tokenizer(
    input_text,
    return_tensors="pt",
    truncation=True,
    max_length=2048,
).to(model.device)

# Generate summary
with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=200,
        pad_token_id=tokenizer.eos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        num_beams=4,
        repetition_penalty=1.2,
        do_sample=False
    )

# Decode and print result
summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("📌 Model Output:\n", summary)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 📌 Model Output:
#
# [INST] Ringkas ulasan berikut menjadi satu paragraf singkat tanpa mengulang kata-kata secara utuh:
#
# Buat ringkasan dari teks berikut ke dalam satu paragraf:
# Saya membeli produk ini karena banyak review positif yang saya lihat sebelumnya. Setelah barang sampai, saya langsung coba dan ternyata kualitasnya sangat memuaskan. Materialnya terasa kokoh dan sesuai deskripsi. Pengiriman juga sangat cepat, hanya butuh dua hari untuk sampai di rumah saya di Jakarta. Seller sangat komunikatif dan membantu menjawab semua pertanyaan saya sebelum membeli. Selain itu, kemasan produk sangat rapi dan aman, tidak ada kerusakan sedikit pun. Harganya juga cukup bersaing dibanding toko lain. Saya sudah coba pakai selama seminggu dan sejauh ini tidak ada kendala. Benar-benar pengalaman belanja yang memuaskan dan saya sangat merekomendasikan produk ini kepada orang lain.
# [/INST]
#
# [ENG] Summarize the following text into a single paragraph without repeating words:
# I bought this product because I saw a lot of positive reviews before. After the item arrived, I immediately tried it and the quality was very satisfying. The material felt sturdy and as described. The delivery was also very fast, only taking two days to reach my home in Jakarta. The seller was very communicative and helped answer all my questions before buying. In addition, the packaging of the product was very neat and safe, with no damage at all. The price was also competitive compared to other stores. I have been using it for a week and so far there have been no issues. It has been a very satisfying shopping experience and I highly recommend this product to others.
